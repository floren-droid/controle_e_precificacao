# %% [markdown]
# ### Ambiente teste

# %%
from pricing_brap import dados_pricing, precificacao

analise, controle, caminho = dados_pricing.coletar_pendencias()
analise = precificacao.precificar_interativo(
    analise, caminho, dados_pricing.CONFIG['aba_controle']
)
# ... resto do fluxo
# Out:
# Pendências 4 de 9  (0 já precificada(s))
# ----------------------------------------------------------------
# [1837] LABORATORIO SAO GERALDO RIO POMBA LTDA | Luiz
#
#   Exame: FHER2 - FISH-ERBB2/CEN/HER2(MAMA)
#   Custo total: 800.00
#   Tabela padrão: 1196.0   |   Concorrente: -   |   Negociado: 975.2
#
#   >> Já decidido nesta sessão: 975.20 (margem 18.0%)
#
# Saindo. O que foi precificado está salvo no controle.

# %%
#%pip install -e ..
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Obtaining file:///C:/Users/silvarg1/OneDrive%20-%20afip.com.br/Python_codes/controle_e_precificacao
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for pricing_brap (pyproject.toml): started
#   Building editable for pricing_brap (pyproject.toml): finished with status 'done'
# ...
